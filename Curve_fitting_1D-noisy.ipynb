# %%
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.layers import InputLayer, Dense, Layer
import numpy as np
import matplotlib.pyplot as plt
import time

np.random.seed(123)
tf.random.set_seed(123)

# %%
class NeuralNet:
    # Initialize the class
    def __init__(self, t_train, x_train, t_test, x_test, layers, t_min, t_max):
        self.t_train = t_train
        self.x_train = x_train
        self.t_test = t_test
        self.x_test = x_test
        self.loss_history = {"train": [], "test": []}
        
        # Initialize NNs with given number of layers and domain bounds [t_min, tmax]
        self.t_min = t_min
        self.t_max = t_max
        self.initialize_nn(layers)
    
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]        
        xavier_stddev = np.sqrt(2 / (in_dim + out_dim))
        return tf.Variable(tf.random.truncated_normal([in_dim, out_dim], stddev=xavier_stddev), dtype=tf.float32)
    
    def initialize_nn(self, layers):        
        """Functions used to establish the initial neural network"""
        weights = []
        biases = []
        num_layers = len(layers) 
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32))
            weights.append(W)
            biases.append(b)        
        self.weights = weights
        self.biases = biases
        self.trainable_variables = self.weights + self.biases
       
    def net(self, X):
        H = 2.0 * (X - self.t_min) / (self.t_max - self.t_min) - 1.0
        for l in range(0, len(self.weights) - 1):
            W = self.weights[l]
            b = self.biases[l]
            H = tf.sin(tf.add(tf.matmul(H, W), b))
        W = self.weights[-1]
        b = self.biases[-1]
        Y = tf.add(tf.matmul(H, W), b)
        return Y

    @tf.function
    def loss_train(self):
        x_pred = self.net(self.t_train)
        loss = tf.reduce_mean(tf.square(self.x_train - x_pred)) * 10
        return loss
    
    @tf.function
    def loss_test(self):
        x_pred = self.net(self.t_test)
        loss = tf.reduce_mean(tf.square(self.x_test - x_pred)) * 10
        return loss

    def get_test_error(self):
        x_pred = self.net(self.t_test)
        error_x = tf.norm(self.x_test - x_pred, 2) / tf.norm(self.x_test, 2)
        return error_x
    
    def train(self, nIter: int, learning_rate: float, idxOpt: int):
        """Function used for training the model"""
        if idxOpt == 1:
            # mode 1: running the Gradient Descent optimization
            self.optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate)
        elif idxOpt == 2:
            # mode 2: running the Adam optimization
            self.optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
        else:
            raise ValueError("Unsupported idxOpt")

        varlist = self.trainable_variables
        start_time = time.time()

        for it in range(nIter):
            self.optimizer.minimize(self.loss_train, varlist)
            
            # Print
            if it % 100 == 0:
                elapsed = time.time() - start_time
                loss_train = self.loss_train().numpy()
                loss_test = self.loss_test().numpy()
                self.loss_history["train"].append(loss_train)
                self.loss_history["test"].append(loss_test)
                print('It: %d, Train Loss: %.3e, Test Loss: %.3e, Time: %.2f' % 
                      (it, loss_train, loss_test, elapsed))
                start_time = time.time()

# %%
# %matplotlib inline
def plot(t_all, x_all, x_true, pred_all, t_train, x_train, title: str):
    fig = plt.figure(figsize=(21, 24))

    ax = plt.subplot(311)
    ax.plot(t_all, x_true, "r", label="Exact Solution")
    ax.plot(t_all, pred_all, "b--", label="Prediction")
    ax.scatter(t_train, x_train, s=30, c="g", label="Train Data Point")
    ax.legend()
    ax.set_xlabel("$t$", fontsize = 12)
    ax.set_ylabel("$x$", fontsize = 12, rotation = 0)
    ax.set_title("$Fitting$", fontsize = 15)

    ax = plt.subplot(312)
    ax.plot(t_all, pred_all - x_all, "b-")
    ax.set_xlabel("$t$", fontsize = 12)
    ax.set_ylabel("Prediction - Exact Solution", fontsize = 12, rotation = 90)
    ax.set_title("Difference between Prediction and Exact Solution", fontsize = 15)

    ax = plt.subplot(313)
    loss_train = np.array(model.loss_history["train"])
    loss_test = np.array(model.loss_history["test"])
    ax.scatter(np.arange(loss_train.size) * 100, loss_train, s=30, marker="x", label="Train Loss")
    ax.scatter(np.arange(loss_train.size) * 100, loss_test, s=30, marker="+", label="Test Loss")
    ax.legend()
    ax.set_xlabel("$iterations$", fontsize = 12)
    ax.set_ylabel("Loss", fontsize = 12, rotation = 90)
    ax.set_yscale("log")
    ax.set_title('Loss Curve', fontsize = 15)
    
    plt.gcf().text(0.02, 0.9, title, fontsize=20)

# %%
# Create data points and get random split of train, test data sets by index slicing
n_total = 1000
train_ratio = 0.8
n_train = int(n_total * train_ratio)

t_all = np.linspace(-1, 1, n_total)
noise = np.random.normal(loc=0.0, scale=0.01, size=t_all.shape)
x_all = np.sin(5 * t_all) * (1 + noise)
x_true = np.sin(5 * t_all)

train_indices = np.zeros(t_all.size, dtype=bool)
train_indices[:n_train] = True
np.random.shuffle(train_indices)

t_train = t_all[train_indices]
x_train = x_all[train_indices]
t_train = tf.reshape(tf.cast(t_train, dtype = tf.float32), shape=(-1, 1))
x_train = tf.reshape(tf.cast(x_train, dtype = tf.float32), shape=(-1, 1))

t_test = t_all[~train_indices]
x_test = x_all[~train_indices]
t_test = tf.reshape(tf.cast(t_test, dtype = tf.float32), shape=(-1, 1))
x_test = tf.reshape(tf.cast(x_test, dtype = tf.float32), shape=(-1, 1))

model = NeuralNet(
    t_train=t_train, x_train=x_train, t_test=t_test, x_test=x_test,
    layers=[1, 100, 100, 100, 1], t_min=t_all.min(0), t_max=t_all.max(0))

start_time = time.time()
model.train(2000, learning_rate=0.01, idxOpt=1)
elapsed = time.time() - start_time
print('Training time: %.4f' % (elapsed))

pred_all = model.net(tf.reshape(tf.cast(t_all, dtype=tf.float32), shape=(-1, 1))).numpy().flatten()
print('Norm of Differnece: %e' % (model.get_test_error().numpy()))

plot(t_all, x_all, x_true, pred_all, t_train, x_train, title="Noise ratio 0.01")
# Out:
# It: 0, Train Loss: 4.988e+00, Test Loss: 5.339e+00, Time: 0.81
# It: 100, Train Loss: 4.923e+00, Test Loss: 5.325e+00, Time: 0.54
# It: 200, Train Loss: 4.919e+00, Test Loss: 5.320e+00, Time: 0.55
# It: 300, Train Loss: 4.911e+00, Test Loss: 5.311e+00, Time: 0.53
# It: 400, Train Loss: 4.860e+00, Test Loss: 5.255e+00, Time: 0.53
# It: 500, Train Loss: 4.832e-02, Test Loss: 4.715e-02, Time: 0.54
# It: 600, Train Loss: 2.806e-03, Test Loss: 2.868e-03, Time: 0.53
# It: 700, Train Loss: 2.763e-03, Test Loss: 2.825e-03, Time: 0.53
# It: 800, Train Loss: 2.721e-03, Test Loss: 2.783e-03, Time: 0.53
# It: 900, Train Loss: 2.681e-03, Test Loss: 2.744e-03, Time: 0.53
# It: 1000, Train Loss: 2.643e-03, Test Loss: 2.706e-03, Time: 0.55
# It: 1100, Train Loss: 2.607e-03, Test Loss: 2.670e-03, Time: 0.53
# It: 1200, Train Loss: 2.572e-03, Test Loss: 2.635e-03, Time: 0.53
# It: 1300, Train Loss: 2.539e-03, Test Loss: 2.602e-03, Time: 0.53
# It: 1400, Train Loss: 2.506e-03, Test Loss: 2.570e-03, Time: 0.53
# It: 1500, Train Loss: 2.476e-03, Test Loss: 2.539e-03, Time: 0.52
# It: 1600, Train Loss: 2.446e-03, Test Loss: 2.510e-03, Time: 0.52
# It: 1700, Train Loss: 2.417e-03, Test Loss: 2.481e-03, Time: 0.55
# It: 1800, Train Loss: 2.390e-03, Test Loss: 2.454e-03, Time: 0.54
# It: 1900, Train Loss: 2.363e-03, Test Loss: 2.427e-03, Time: 0.53
# Training time: 11.6875
# Norm of Differnece: 2.092659e-02

# %%
# Create data points and get random split of train, test data sets by index slicing
n_total = 1000
train_ratio = 0.8
n_train = int(n_total * train_ratio)

t_all = np.linspace(-1, 1, n_total)
x_true = np.sin(5 * t_all)
noise = np.random.normal(loc=0.0, scale=0.1, size=t_all.shape)
x_all = np.sin(5 * t_all) * (1 + noise)
x_true = np.sin(5 * t_all)

train_indices = np.zeros(t_all.size, dtype=bool)
train_indices[:n_train] = True
np.random.shuffle(train_indices)

t_train = t_all[train_indices]
x_train = x_all[train_indices]
t_train = tf.reshape(tf.cast(t_train, dtype = tf.float32), shape=(-1, 1))
x_train = tf.reshape(tf.cast(x_train, dtype = tf.float32), shape=(-1, 1))

t_test = t_all[~train_indices]
x_test = x_all[~train_indices]
t_test = tf.reshape(tf.cast(t_test, dtype = tf.float32), shape=(-1, 1))
x_test = tf.reshape(tf.cast(x_test, dtype = tf.float32), shape=(-1, 1))

model = NeuralNet(
    t_train=t_train, x_train=x_train, t_test=t_test, x_test=x_test,
    layers=[1, 100, 100, 100, 1], t_min=t_all.min(0), t_max=t_all.max(0))

start_time = time.time()
model.train(2000, learning_rate=0.01, idxOpt=1)
elapsed = time.time() - start_time
print('Training time: %.4f' % (elapsed))

pred_all = model.net(tf.reshape(tf.cast(t_all, dtype=tf.float32), shape=(-1, 1))).numpy().flatten()
print('Norm of Differnece: %e' % (model.get_test_error().numpy()))

plot(t_all, x_all, x_true, pred_all, t_train, x_train, title="Noise ratio 0.1")
# Out:
# It: 0, Train Loss: 5.322e+00, Test Loss: 5.360e+00, Time: 0.18
# It: 100, Train Loss: 5.018e+00, Test Loss: 5.450e+00, Time: 0.66
# It: 200, Train Loss: 5.016e+00, Test Loss: 5.449e+00, Time: 0.64
# It: 300, Train Loss: 5.015e+00, Test Loss: 5.448e+00, Time: 0.66
# It: 400, Train Loss: 5.014e+00, Test Loss: 5.447e+00, Time: 0.71
# It: 500, Train Loss: 5.013e+00, Test Loss: 5.447e+00, Time: 0.70
# It: 600, Train Loss: 5.012e+00, Test Loss: 5.446e+00, Time: 0.70
# It: 700, Train Loss: 5.011e+00, Test Loss: 5.445e+00, Time: 0.68
# It: 800, Train Loss: 5.010e+00, Test Loss: 5.443e+00, Time: 0.67
# It: 900, Train Loss: 5.008e+00, Test Loss: 5.441e+00, Time: 0.65
# It: 1000, Train Loss: 5.005e+00, Test Loss: 5.438e+00, Time: 0.65
# It: 1100, Train Loss: 4.999e+00, Test Loss: 5.430e+00, Time: 0.71
# It: 1200, Train Loss: 4.979e+00, Test Loss: 5.407e+00, Time: 0.70
# It: 1300, Train Loss: 4.860e+00, Test Loss: 5.270e+00, Time: 0.70
# It: 1400, Train Loss: 5.222e+00, Test Loss: 5.561e+00, Time: 0.68
# It: 1500, Train Loss: 1.033e+00, Test Loss: 1.057e+00, Time: 0.65
# It: 1600, Train Loss: 7.366e-01, Test Loss: 7.313e-01, Time: 0.65
# It: 1700, Train Loss: 4.593e-01, Test Loss: 4.514e-01, Time: 0.62
# It: 1800, Train Loss: 5.924e-02, Test Loss: 5.825e-02, Time: 0.68
# It: 1900, Train Loss: 5.740e-02, Test Loss: 5.603e-02, Time: 0.70
# Training time: 13.8190
# Norm of Differnece: 1.008182e-01

# %%
# Create data points and get random split of train, test data sets by index slicing
n_total = 1000
train_ratio = 0.8
n_train = int(n_total * train_ratio)

t_all = np.linspace(-1, 1, n_total)
x_true = np.sin(5 * t_all)
noise = np.random.normal(loc=0.0, scale=0.5, size=t_all.shape)
x_all = np.sin(5 * t_all) * (1 + noise)
x_true = np.sin(5 * t_all)

train_indices = np.zeros(t_all.size, dtype=bool)
train_indices[:n_train] = True
np.random.shuffle(train_indices)

t_train = t_all[train_indices]
x_train = x_all[train_indices]
t_train = tf.reshape(tf.cast(t_train, dtype = tf.float32), shape=(-1, 1))
x_train = tf.reshape(tf.cast(x_train, dtype = tf.float32), shape=(-1, 1))

t_test = t_all[~train_indices]
x_test = x_all[~train_indices]
t_test = tf.reshape(tf.cast(t_test, dtype = tf.float32), shape=(-1, 1))
x_test = tf.reshape(tf.cast(x_test, dtype = tf.float32), shape=(-1, 1))

model = NeuralNet(
    t_train=t_train, x_train=x_train, t_test=t_test, x_test=x_test,
    layers=[1, 100, 100, 100, 1], t_min=t_all.min(0), t_max=t_all.max(0))

start_time = time.time()
model.train(2000, learning_rate=0.01, idxOpt=1)
elapsed = time.time() - start_time
print('Training time: %.4f' % (elapsed))

pred_all = model.net(tf.reshape(tf.cast(t_all, dtype=tf.float32), shape=(-1, 1))).numpy().flatten()
print('Norm of Differnece: %e' % (model.get_test_error().numpy()))

plot(t_all, x_all, x_true, pred_all, t_train, x_train, title="Noise ratio 0.5")
# Out:
# It: 0, Train Loss: 6.463e+00, Test Loss: 7.203e+00, Time: 0.17
# It: 100, Train Loss: 6.001e+00, Test Loss: 6.830e+00, Time: 0.57
# It: 200, Train Loss: 5.999e+00, Test Loss: 6.826e+00, Time: 0.60
# It: 300, Train Loss: 5.993e+00, Test Loss: 6.819e+00, Time: 0.59
# It: 400, Train Loss: 5.957e+00, Test Loss: 6.777e+00, Time: 0.65
# It: 500, Train Loss: 1.281e+00, Test Loss: 1.284e+00, Time: 0.62
# It: 600, Train Loss: 1.276e+00, Test Loss: 1.272e+00, Time: 0.59
# It: 700, Train Loss: 1.276e+00, Test Loss: 1.272e+00, Time: 0.60
# It: 800, Train Loss: 1.276e+00, Test Loss: 1.272e+00, Time: 0.55
# It: 900, Train Loss: 1.276e+00, Test Loss: 1.272e+00, Time: 0.56
# It: 1000, Train Loss: 1.275e+00, Test Loss: 1.272e+00, Time: 0.57
# It: 1100, Train Loss: 1.275e+00, Test Loss: 1.272e+00, Time: 0.58
# It: 1200, Train Loss: 1.275e+00, Test Loss: 1.272e+00, Time: 0.57
# It: 1300, Train Loss: 1.275e+00, Test Loss: 1.272e+00, Time: 0.68
# It: 1400, Train Loss: 1.275e+00, Test Loss: 1.272e+00, Time: 0.59
# It: 1500, Train Loss: 1.275e+00, Test Loss: 1.272e+00, Time: 0.57
# It: 1600, Train Loss: 1.275e+00, Test Loss: 1.272e+00, Time: 0.58
# It: 1700, Train Loss: 1.275e+00, Test Loss: 1.271e+00, Time: 0.54
# It: 1800, Train Loss: 1.275e+00, Test Loss: 1.271e+00, Time: 0.57
# It: 1900, Train Loss: 1.275e+00, Test Loss: 1.271e+00, Time: 0.58
# Training time: 11.9988
# Norm of Differnece: 4.282199e-01

# %%
# Create data points and get random split of train, test data sets by index slicing
n_total = 1000
train_ratio = 0.1
n_train = int(n_total * train_ratio)

t_all = np.linspace(-1, 1, n_total)
x_true = np.sin(5 * t_all)
noise = np.random.normal(loc=0.0, scale=0.5, size=t_all.shape)
x_all = np.sin(5 * t_all) * (1 + noise)
x_true = np.sin(5 * t_all)

train_indices = np.zeros(t_all.size, dtype=bool)
train_indices[:n_train] = True
np.random.shuffle(train_indices)

t_train = t_all[train_indices]
x_train = x_all[train_indices]
t_train = tf.reshape(tf.cast(t_train, dtype = tf.float32), shape=(-1, 1))
x_train = tf.reshape(tf.cast(x_train, dtype = tf.float32), shape=(-1, 1))

t_test = t_all[~train_indices]
x_test = x_all[~train_indices]
t_test = tf.reshape(tf.cast(t_test, dtype = tf.float32), shape=(-1, 1))
x_test = tf.reshape(tf.cast(x_test, dtype = tf.float32), shape=(-1, 1))

model = NeuralNet(
    t_train=t_train, x_train=x_train, t_test=t_test, x_test=x_test,
    layers=[1, 100, 100, 100, 1], t_min=t_all.min(0), t_max=t_all.max(0))

start_time = time.time()
model.train(20000, learning_rate=0.01, idxOpt=2)
elapsed = time.time() - start_time
print('Training time: %.4f' % (elapsed))

pred_all = model.net(tf.reshape(tf.cast(t_all, dtype=tf.float32), shape=(-1, 1))).numpy().flatten()
print('Norm of Differnece: %e' % (model.get_test_error().numpy()))

plot(t_all, x_all, x_true, pred_all, t_train, x_train, title="Overfitting Example: Noise ratio 0.5")
# Out:
# It: 0, Train Loss: 1.362e+01, Test Loss: 1.532e+01, Time: 0.17
# It: 100, Train Loss: 9.558e-01, Test Loss: 1.553e+00, Time: 0.72
# It: 200, Train Loss: 9.449e-01, Test Loss: 1.525e+00, Time: 0.72
# It: 300, Train Loss: 9.416e-01, Test Loss: 1.529e+00, Time: 0.68
# It: 400, Train Loss: 9.406e-01, Test Loss: 1.528e+00, Time: 0.68
# It: 500, Train Loss: 1.048e+00, Test Loss: 1.606e+00, Time: 0.73
# It: 600, Train Loss: 9.315e-01, Test Loss: 1.539e+00, Time: 0.73
# It: 700, Train Loss: 9.243e-01, Test Loss: 1.568e+00, Time: 0.80
# It: 800, Train Loss: 9.252e-01, Test Loss: 1.561e+00, Time: 0.72
# It: 900, Train Loss: 9.232e-01, Test Loss: 1.571e+00, Time: 0.72
# It: 1000, Train Loss: 9.224e-01, Test Loss: 1.569e+00, Time: 0.65
# It: 1100, Train Loss: 9.281e-01, Test Loss: 1.567e+00, Time: 0.70
# It: 1200, Train Loss: 9.170e-01, Test Loss: 1.561e+00, Time: 0.73
# It: 1300, Train Loss: 9.027e-01, Test Loss: 1.564e+00, Time: 0.75
# It: 1400, Train Loss: 8.997e-01, Test Loss: 1.570e+00, Time: 0.78
# It: 1500, Train Loss: 8.998e-01, Test Loss: 1.578e+00, Time: 0.71
# It: 1600, Train Loss: 8.959e-01, Test Loss: 1.581e+00, Time: 0.72
# It: 1700, Train Loss: 8.981e-01, Test Loss: 1.585e+00, Time: 0.70
# It: 1800, Train Loss: 8.944e-01, Test Loss: 1.585e+00, Time: 0.70
# It: 1900, Train Loss: 8.939e-01, Test Loss: 1.587e+00, Time: 0.70
# It: 2000, Train Loss: 8.936e-01, Test Loss: 1.586e+00, Time: 0.78
# It: 2100, Train Loss: 8.928e-01, Test Loss: 1.588e+00, Time: 0.75
